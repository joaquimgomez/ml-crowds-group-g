# %% [markdown]
# # Imports

# %%
from utils import *

import os

import matplotlib.pyplot as plt
from matplotlib import colors

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Task 4.1 - Static1000Crowd

# %%
os.chdir("../output/Task4-1-Static1000Crowd/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

# %%
data = pd.read_csv(file_path, delimiter=" ")

ID_SUSCEPTIBLE = 1
ID_INFECTED = 0
ID_REMOVED = 2

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

# %%
infected = group_counts["group-i"]
susceptible = group_counts["group-s"]
recovered = group_counts["group-r"]
simulation_time = group_counts['simTime']

plt.figure(figsize=(12,6))
#plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

#plt.title("Task 4.5")

plt.show()

# %% [markdown]
# # Task 4.2 - Static1000Crowd

# %%
os.chdir("../../output/Task4-2-Static1000Crowd/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

# %%
data = pd.read_csv(file_path, delimiter=" ")

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

# %%
infected = group_counts["group-i"].values
susceptible = group_counts["group-s"].values
recovered = group_counts["group-r"].values
simulation_time = group_counts['simTime'].values

plt.figure(figsize=(12,6))

#plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

#plt.title("Task 4.2")

plt.show()

# %% [markdown]
# # Task 4.3 - Corridor

# %%
os.chdir("../../output/Task4-3-Corridor/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

# %%
data = pd.read_csv(file_path, delimiter=" ")

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

# %%
group_counts
# Out:
#      simTime  group-s  group-i  group-r
# 0        0.0      200        0        0
# 1        0.5      189       11        0
# 2        0.6      189       11        0
# 3        0.7      189       11        0
# 4        0.8      189       11        0
# ..       ...      ...      ...      ...
# 539     74.5      164       36        0
# 540     74.6      164       36        0
# 541     75.6      164       36        0
# 542     75.7      164       36        0
# 543     76.9      164       36        0
#
# [544 rows x 4 columns]

# %%
infected = group_counts["group-i"].values
susceptible = group_counts["group-s"].values
recovered = group_counts["group-r"].values
simulation_time = group_counts['simTime'].values

plt.figure(figsize=(12,6))

#plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

#plt.title("Task 4.3 - Corridor")

plt.show()

# %% [markdown]
# # Task 5 - Test1

# %%
os.chdir("../../output/Task5-Test1/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

data = pd.read_csv(file_path, delimiter=" ")
print(file_path)

ID_SUSCEPTIBLE = 1
ID_INFECTED = 0
ID_REMOVED = 2

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

infected = group_counts["group-i"].values
susceptible = group_counts["group-s"].values
recovered = group_counts["group-r"].values
simulation_time = group_counts['simTime'].values

plt.figure(figsize=(12,6))

plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

plt.show()
# Out:
# /Users/joaquimgomez/Library/Mobile Documents/com~apple~CloudDocs/TUM/Data Engineering and Analytics/Semester 3/IN2106 - Master's Practical Course/ml-crowds-group-g/Exercise 2/output/Task5-Test1/SIRInformation.csv

# %% [markdown]
# # Task 5 - Test 2 (Infection rate = 0.05 & Recovery rate = 0.05)

# %%
os.chdir("../../output/Task5-Test2-EqualInfAndRec/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

data = pd.read_csv(file_path, delimiter=" ")
print(file_path)

ID_SUSCEPTIBLE = 1
ID_INFECTED = 0
ID_REMOVED = 2

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

infected = group_counts["group-i"].values
susceptible = group_counts["group-s"].values
recovered = group_counts["group-r"].values
simulation_time = group_counts['simTime'].values

plt.figure(figsize=(12,6))

plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

plt.show()
# Out:
# /Users/joaquimgomez/Library/Mobile Documents/com~apple~CloudDocs/TUM/Data Engineering and Analytics/Semester 3/IN2106 - Master's Practical Course/ml-crowds-group-g/Exercise 2/output/Task5-Test2-EqualInfAndRec/SIRInformation.csv

# %% [markdown]
# # Task 5 - Test 2 (Infection rate = 0.005 & Recovery rate = 0.05)

# %%
os.chdir("../../output/Task5-Test2-LessInfAndMoreRec/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

data = pd.read_csv(file_path, delimiter=" ")
print(file_path)

ID_SUSCEPTIBLE = 1
ID_INFECTED = 0
ID_REMOVED = 2

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

infected = group_counts["group-i"].values
susceptible = group_counts["group-s"].values
recovered = group_counts["group-r"].values
simulation_time = group_counts['simTime'].values

plt.figure(figsize=(12,6))

plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

plt.show()
# Out:
# /Users/joaquimgomez/Library/Mobile Documents/com~apple~CloudDocs/TUM/Data Engineering and Analytics/Semester 3/IN2106 - Master's Practical Course/ml-crowds-group-g/Exercise 2/output/Task5-Test2-LessInfAndMoreRec/SIRInformation.csv

# %% [markdown]
# # Task 5 - Test 2 (Infection rate = 0.005 & Recovery rate = 0.05 & 100 infections at the beginning)

# %%
os.chdir("../../output/Task5-Test2-LessInfAndMoreRec100/")
file_path = os.path.join(os.getcwd(), "SIRInformation.csv")

data = pd.read_csv(file_path, delimiter=" ")
print(file_path)

ID_SUSCEPTIBLE = 1
ID_INFECTED = 0
ID_REMOVED = 2

group_counts = file_df_to_count_df(data, ID_INFECTED=ID_INFECTED, ID_SUSCEPTIBLE=ID_SUSCEPTIBLE, ID_REMOVED=ID_REMOVED)

infected = group_counts["group-i"].values
susceptible = group_counts["group-s"].values
recovered = group_counts["group-r"].values
simulation_time = group_counts['simTime'].values

plt.figure(figsize=(12,6))

plt.plot(simulation_time, recovered, color="green")
plt.plot(simulation_time, infected, color="red")
plt.plot(simulation_time, susceptible, color="blue")

plt.xlabel("Simulation Time")
plt.ylabel("Agents")
plt.legend(["Recovered", "Infected", "Susceptible"], loc="lower right" )

plt.show()
# Out:
# /Users/joaquimgomez/Library/Mobile Documents/com~apple~CloudDocs/TUM/Data Engineering and Analytics/Semester 3/IN2106 - Master's Practical Course/ml-crowds-group-g/Exercise 2/output/Task5-Test2-LessInfAndMoreRec100/SIRInformation.csv
